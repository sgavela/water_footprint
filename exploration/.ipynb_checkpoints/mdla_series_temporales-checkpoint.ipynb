# %%
import pandas as pd
from pmdarima.arima import auto_arima, ADFTest
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle('../data/df6.pkl')
data.head(5)
# Out:
#    ID  DELTA  YEAR_DAY       DATE  MEAN_CONSUMPTION  VARIANCE_CONSUMPTION  \
# 0   0  243.0         0 2019-02-01        282.893151          11453.639651
# 1   0  236.0         1 2019-02-02        282.893151          11453.639651
# 2   0  335.0         2 2019-02-03        282.893151          11453.639651
# 3   0  252.0         3 2019-02-04        282.893151          11453.639651
# 4   0  220.0         4 2019-02-05        282.893151          11453.639651
#
#    WEEKDAY  IS_WEEKEND  sin_WEEKDAY  cos_WEEKDAY  sin_year_day  cos_year_day  \
# 0        4           0    -0.433884    -0.900969      0.000000      1.000000
# 1        5           1    -0.974928    -0.222521      0.017213      0.999852
# 2        6           1    -0.781831     0.623490      0.034422      0.999407
# 3        0           0     0.000000     1.000000      0.051620      0.998667
# 4        1           0     0.781831     0.623490      0.068802      0.997630
#
#    PRECIPITATIONS  MIN_TEMP  MEAN_TEMP  MAX_TEMP  SUN  IS_GOOD
# 0             0.0      16.5       17.6      18.7  7.1        1
# 1             0.0       9.8       13.4      17.1  6.1        1
# 2             0.0       7.7       10.6      13.6  9.3        1
# 3             0.0       4.1       10.6      17.2  9.3        1
# 4             0.0       7.5       14.6      21.6  9.2        1

# %%
data_st = data[data['ID'] == 4]

# %%
data_st.head(400)
# Out:
#       ID   DELTA  YEAR_DAY       DATE  MEAN_CONSUMPTION  VARIANCE_CONSUMPTION  \
# 1460   4  247.56         0 2019-02-01        265.456329           6416.593867
# 1461   4  235.67         1 2019-02-02        265.456329           6416.593867
# 1462   4  254.33         2 2019-02-03        265.456329           6416.593867
# 1463   4  412.00         3 2019-02-04        265.456329           6416.593867
# 1464   4  269.00         4 2019-02-05        265.456329           6416.593867
# ...   ..     ...       ...        ...               ...                   ...
# 1820   4  263.06       360 2020-01-27        265.456329           6416.593867
# 1821   4  303.94       361 2020-01-28        265.456329           6416.593867
# 1822   4  421.00       362 2020-01-29        265.456329           6416.593867
# 1823   4  420.00       363 2020-01-30        265.456329           6416.593867
# 1824   4  254.00       364 2020-01-31        265.456329           6416.593867
#
#       WEEKDAY  IS_WEEKEND  sin_WEEKDAY  cos_WEEKDAY  sin_year_day  \
# 1460        4           0    -0.433884    -0.900969      0.000000
# 1461        5           1    -0.974928    -0.222521      0.017213
# 1462        6           1    -0.781831     0.623490      0.034422
# 1463        0           0     0.000000     1.000000      0.051620
# 1464        1           0     0.781831     0.623490      0.068802
# ...       ...         ...          ...          ...           ...
# 1820        0           0     0.000000     1.000000     -0.085965
# 1821        1           0     0.781831     0.623490     -0.068802
# 1822        2           0     0.974928    -0.222521     -0.051620
# 1823        3           0     0.433884    -0.900969     -0.034422
# 1824        4           0    -0.433884    -0.900969     -0.017213
#
#       cos_year_day  PRECIPITATIONS  MIN_TEMP  MEAN_TEMP  MAX_TEMP  SUN  \
# 1460      1.000000             0.0      16.5       17.6      18.7  7.1
# 1461      0.999852             0.0       9.8       13.4      17.1  6.1
# 1462      0.999407             0.0       7.7       10.6      13.6  9.3
# 1463      0.998667             0.0       4.1       10.6      17.2  9.3
# 1464      0.997630             0.0       7.5       14.6      21.6  9.2
# ...            ...             ...       ...        ...       ...  ...
# 1820      0.996298             0.0       7.6       13.0      18.4  7.6
# 1821      0.997630             0.0      13.8       15.8      17.9  0.4
# 1822      0.998667             0.0      14.7       18.6      22.4  2.4
# 1823      0.999407             0.0      13.0       17.6      22.2  5.3
# 1824      0.999852             0.0      14.5       19.1      23.7  9.2
#
#       IS_GOOD
# 1460        1
# 1461        1
# 1462        1
# 1463        1
# 1464        1
# ...       ...
# 1820        1
# 1821        1
# 1822        1
# 1823        1
# 1824        1
#
# [365 rows x 18 columns]

# %%
list(data_st.columns)
# Out:
# ['ID',
#  'DELTA',
#  'YEAR_DAY',
#  'DATE',
#  'MEAN_CONSUMPTION',
#  'VARIANCE_CONSUMPTION',
#  'WEEKDAY',
#  'IS_WEEKEND',
#  'sin_WEEKDAY',
#  'cos_WEEKDAY',
#  'sin_year_day',
#  'cos_year_day',
#  'PRECIPITATIONS',
#  'MIN_TEMP',
#  'MEAN_TEMP',
#  'MAX_TEMP',
#  'SUN',
#  'IS_GOOD']

# %%
data_st = data_st.drop(['ID',
 'YEAR_DAY',
 'MEAN_CONSUMPTION',
 'VARIANCE_CONSUMPTION',
 'WEEKDAY',
 'IS_WEEKEND',
 'sin_WEEKDAY',
 'cos_WEEKDAY',
 'sin_year_day',
 'cos_year_day',
 'PRECIPITATIONS',
 'MIN_TEMP',
 'MEAN_TEMP',
 'MAX_TEMP',
 'SUN',
 'IS_GOOD'], axis=1)

# %%
data_st.head(5)
# Out:
#        DELTA       DATE
# 1460  247.56 2019-02-01
# 1461  235.67 2019-02-02
# 1462  254.33 2019-02-03
# 1463  412.00 2019-02-04
# 1464  269.00 2019-02-05

# %%
data_st.set_index('DATE', inplace = True)

# %%
data_st.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
len(data_st)
# Out:
# 365

# %%
#Stationarity is an important concept in time-series and any time-series 
# data should undergo a stationarity test before proceeding with a model.
#We use the ‘Augmented Dickey-Fuller Test’ to check whether the data is 
# stationary or not which is available in the ‘pmdarima’ package.

augmented_dickey_fuller_test = ADFTest(alpha = 0.05)
augmented_dickey_fuller_test.should_diff(data_st)

#From the above, we can conclude that the data is non-stationary. Hence, 
# we would need to use the “Integrated (I)” concept, denoted by value ‘d’ 
# in time series to make the data stationary while building the Auto ARIMA model.
# Out:
# (0.01, False)

# %%
train = data_st[:(365-14)]
test = data_st[-14:]
plt.plot(train)
plt.plot(test)
#plot train test

# %% [markdown]
# ARIMA
#
# Auto-Regressive (p) -> Number of autoregressive terms.
#
# Integrated (d) -> Number of nonseasonal differences needed for stationarity.
#
# Moving Average (q) -> Number of lagged forecast errors in the prediction equation.

# %%
arima_model = auto_arima(train, start_p=0, d=1, start_q=0, max_p=5, max_d=5, max_q=5, start_P=0, D=1, start_Q=0, max_P=5, max_D=5, max_Q=5, m=12, seasonal=True, error_action='warn', trace=True, supress_warnings=True, stepwise=True, random_state=2517, n_fits=50)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=4279.687, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=4073.336, Time=0.18 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.92 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=4174.719, Time=0.06 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=4052.249, Time=0.50 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=4042.533, Time=1.03 sec
#  ARIMA(1,1,0)(4,1,0)[12]             : AIC=4027.609, Time=2.02 sec
#  ARIMA(1,1,0)(5,1,0)[12]             : AIC=4018.726, Time=4.43 sec
#  ARIMA(1,1,0)(5,1,1)[12]             : AIC=inf, Time=19.88 sec
#  ARIMA(1,1,0)(4,1,1)[12]             : AIC=inf, Time=11.78 sec
#  ARIMA(0,1,0)(5,1,0)[12]             : AIC=4120.055, Time=3.14 sec
#  ARIMA(2,1,0)(5,1,0)[12]             : AIC=3986.699, Time=4.54 sec
#  ARIMA(2,1,0)(4,1,0)[12]             : AIC=3994.829, Time=2.11 sec
#  ARIMA(2,1,0)(5,1,1)[12]             : AIC=inf, Time=22.87 sec
#  ARIMA(2,1,0)(4,1,1)[12]             : AIC=inf, Time=8.38 sec
#  ARIMA(3,1,0)(5,1,0)[12]             : AIC=3959.104, Time=5.02 sec
#  ARIMA(3,1,0)(4,1,0)[12]             : AIC=3969.091, Time=2.87 sec
#  ARIMA(3,1,0)(5,1,1)[12]             : AIC=inf, Time=20.31 sec
#  ARIMA(3,1,0)(4,1,1)[12]             : AIC=inf, Time=10.24 sec
#  ARIMA(4,1,0)(5,1,0)[12]             : AIC=3938.540, Time=5.92 sec
#  ARIMA(4,1,0)(4,1,0)[12]             : AIC=3947.003, Time=4.26 sec
#  ARIMA(4,1,0)(5,1,1)[12]             : AIC=inf, Time=24.57 sec
#  ARIMA(4,1,0)(4,1,1)[12]             : AIC=inf, Time=18.74 sec
#  ARIMA(5,1,0)(5,1,0)[12]             : AIC=3924.594, Time=8.12 sec
#  ARIMA(5,1,0)(4,1,0)[12]             : AIC=3932.846, Time=5.90 sec
#  ARIMA(5,1,0)(5,1,1)[12]             : AIC=inf, Time=37.47 sec
#  ARIMA(5,1,0)(4,1,1)[12]             : AIC=inf, Time=19.40 sec
#  ARIMA(5,1,1)(5,1,0)[12]             : AIC=3888.607, Time=35.16 sec
#  ARIMA(5,1,1)(4,1,0)[12]             : AIC=3895.890, Time=25.44 sec
#  ARIMA(5,1,1)(5,1,1)[12]             : AIC=inf, Time=46.33 sec
#  ARIMA(5,1,1)(4,1,1)[12]             : AIC=inf, Time=33.35 sec
#  ARIMA(4,1,1)(5,1,0)[12]             : AIC=3887.010, Time=37.33 sec
#  ARIMA(4,1,1)(4,1,0)[12]             : AIC=3894.076, Time=28.49 sec
#  ARIMA(4,1,1)(5,1,1)[12]             : AIC=inf, Time=54.48 sec
#  ARIMA(4,1,1)(4,1,1)[12]             : AIC=inf, Time=23.22 sec
#  ARIMA(3,1,1)(5,1,0)[12]             : AIC=3886.483, Time=31.94 sec
#  ARIMA(3,1,1)(4,1,0)[12]             : AIC=3893.795, Time=13.14 sec
#  ARIMA(3,1,1)(5,1,1)[12]             : AIC=inf, Time=40.45 sec
#  ARIMA(3,1,1)(4,1,1)[12]             : AIC=inf, Time=19.95 sec
#  ARIMA(2,1,1)(5,1,0)[12]             : AIC=3889.200, Time=29.46 sec
#  ARIMA(3,1,2)(5,1,0)[12]             : AIC=3885.122, Time=20.74 sec
#  ARIMA(3,1,2)(4,1,0)[12]             : AIC=3893.399, Time=10.30 sec
#  ARIMA(3,1,2)(5,1,1)[12]             : AIC=inf, Time=45.21 sec
#  ARIMA(3,1,2)(4,1,1)[12]             : AIC=inf, Time=20.75 sec
#  ARIMA(2,1,2)(5,1,0)[12]             : AIC=3890.214, Time=33.32 sec
#  ARIMA(4,1,2)(5,1,0)[12]             : AIC=3887.287, Time=46.14 sec
#  ARIMA(3,1,3)(5,1,0)[12]             : AIC=3893.094, Time=39.13 sec
#  ARIMA(2,1,3)(5,1,0)[12]             : AIC=3884.358, Time=38.72 sec
#  ARIMA(2,1,3)(4,1,0)[12]             : AIC=3891.616, Time=17.82 sec
#  ARIMA(2,1,3)(5,1,1)[12]             : AIC=inf, Time=45.49 sec
#  ARIMA(2,1,3)(4,1,1)[12]             : AIC=inf, Time=25.62 sec
#  ARIMA(1,1,3)(5,1,0)[12]             : AIC=3889.848, Time=34.51 sec
#  ARIMA(2,1,4)(5,1,0)[12]             : AIC=3889.380, Time=41.18 sec
#  ARIMA(1,1,2)(5,1,0)[12]             : AIC=3882.002, Time=21.12 sec
#  ARIMA(1,1,2)(4,1,0)[12]             : AIC=3890.134, Time=9.42 sec
#  ARIMA(1,1,2)(5,1,1)[12]             : AIC=inf, Time=37.63 sec
#  ARIMA(1,1,2)(4,1,1)[12]             : AIC=inf, Time=17.21 sec
#  ARIMA(0,1,2)(5,1,0)[12]             : AIC=3887.985, Time=28.64 sec
#  ARIMA(1,1,1)(5,1,0)[12]             : AIC=3888.318, Time=26.31 sec
#  ARIMA(0,1,1)(5,1,0)[12]             : AIC=3888.432, Time=26.98 sec
#  ARIMA(0,1,3)(5,1,0)[12]             : AIC=3887.802, Time=18.71 sec
#  ARIMA(1,1,2)(5,1,0)[12] intercept   : AIC=3887.907, Time=45.19 sec
#
# Best model:  ARIMA(1,1,2)(5,1,0)[12]
# Total fit time: 1313.901 seconds

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  351
# Model:             SARIMAX(1, 1, 2)x(5, 1, [], 12)   Log Likelihood               -1932.001
# Date:                             Sun, 03 Apr 2022   AIC                           3882.002
# Time:                                     20:06:07   BIC                           3916.410
# Sample:                                          0   HQIC                          3895.715
#                                              - 351
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7462      0.112      6.681      0.000       0.527       0.965
# ma.L1         -1.7991      0.090    -19.974      0.000      -1.976      -1.623
# ma.L2          0.8242      0.083      9.904      0.000       0.661       0.987
# ar.S.L12      -0.8338      0.056    -14.910      0.000      -0.943      -0.724
# ar.S.L24      -0.6577      0.073     -9.068      0.000      -0.800      -0.516
# ar.S.L36      -0.5472      0.083     -6.616      0.000      -0.709      -0.385
# ar.S.L48      -0.4097      0.086     -4.751      0.000      -0.579      -0.241
# ar.S.L60      -0.1992      0.061     -3.244      0.001      -0.320      -0.079
# sigma2      5158.3919    419.284     12.303      0.000    4336.611    5980.173
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 1.32
# Prob(Q):                              0.75   Prob(JB):                         0.52
# Heteroskedasticity (H):               1.91   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Forecasting Test Data

# %%
prediction = pd.DataFrame(arima_model.predict(n_periods = 14), index = test.index)
prediction.columns = ['predicted_delta']
prediction
# Out:
#             predicted_delta
# DATE
# 2020-01-18       259.990252
# 2020-01-19       296.705157
# 2020-01-20       319.610907
# 2020-01-21       262.417150
# 2020-01-22       240.013032
# 2020-01-23       254.701864
# 2020-01-24       234.881156
# 2020-01-25       209.771694
# 2020-01-26       258.232528
# 2020-01-27       282.975395
# 2020-01-28       249.465719
# 2020-01-29       202.514177
# 2020-01-30       227.158203
# 2020-01-31       277.076745

# %%
plt.figure(figsize = (8,5))
plt.plot(train, label = 'Training')
plt.plot(test, label = 'Test')
plt.plot(prediction, label = 'Predicted')
plt.legend(loc = 'upper left')
plt.show()

# %%
mean_squared_error(test['DELTA'], test['predicted_delta'])
# Out:
# 9316.85205547701

# %%
r2_score(test['DELTA'], test['predicted_delta'])
# Out:
# -1.2486316334611383

# %% [markdown]
# R2 compares the fit of the chosen model with that of a horizontal straight line (the null hypothesis). If the chosen model fits worse than a horizontal line, then R2 is negative. Note that R2 is not always the square of anything, so it can have a negative value without violating any rules of math. R2 is negative only when the chosen model does not follow the trend of the data, so fits worse than a horizontal line.

# %%
test.head(14)
# Out:
#              DELTA  predicted_delta
# DATE
# 2020-01-18  365.00       259.990252
# 2020-01-19  387.00       296.705157
# 2020-01-20  370.00       319.610907
# 2020-01-21  293.00       262.417150
# 2020-01-22  287.00       240.013032
# 2020-01-23  361.00       254.701864
# 2020-01-24  203.00       234.881156
# 2020-01-25  272.00       209.771694
# 2020-01-26  282.00       258.232528
# 2020-01-27  263.06       282.975395
# 2020-01-28  303.94       249.465719
# 2020-01-29  421.00       202.514177
# 2020-01-30  420.00       227.158203
# 2020-01-31  254.00       277.076745

# %%
import pandas as pd
from tqdm import tqdm
from pmdarima.arima import auto_arima

# %%
data = pd.read_pickle('../data/df6.pkl')
#Todos los contadores
todos_los_contadores = data['ID'].unique()
todos_los_contadores
# Out:
# array([   0,    1,    2, ..., 2748, 2749, 2756], dtype=int64)

# %%
data_sin_outliers = pd.read_pickle('../data/dataset_sin_outliers.pkl')

# %%
#1ºResetear el indice date como variable (el df que se mete no tiene date como variable)
dataset_a_estudiar = data_sin_outliers.reset_index()
#2ºFiltro por periodo para hacer ARIMA
dataset_a_estudiar = dataset_a_estudiar[dataset_a_estudiar['DATE'] > '2019-10-31']
#3ºUna vez se tiene el filtro de fecha, DATE pasa de nuevo a index
dataset_a_estudiar.set_index('DATE', inplace = True)
dataset_a_estudiar
# Out:
#             DELTA_0    DELTA_1  DELTA_2  DELTA_3  DELTA_4  DELTA_5  DELTA_6  \
# DATE
# 2019-11-01    502.0   0.000000      1.0    531.0   411.85      0.0    233.0
# 2019-11-02    331.0  11.690411      1.0    468.0   343.22      0.0    211.0
# 2019-11-03    307.0   0.000000     16.0    411.0   367.78      0.0    151.0
# 2019-11-04    272.0  20.000000     23.0    350.0   276.00      0.0    258.0
# 2019-11-05    289.0   6.000000     27.0    407.0   298.56      0.0    183.0
# ...             ...        ...      ...      ...      ...      ...      ...
# 2020-01-27    213.0   4.000000     39.0    289.0   263.06      0.0    204.0
# 2020-01-28    232.0   1.000000     40.0    380.0   303.94      0.0    169.0
# 2020-01-29    403.0   2.000000     45.0    404.0   421.00      0.0    195.0
# 2020-01-30    425.0  10.000000     27.0    339.0   420.00      0.0    152.0
# 2020-01-31    255.0  11.690411     59.0    391.0   254.00      0.0    210.0
#
#             DELTA_7   DELTA_8  DELTA_9  ...  DELTA_2739  DELTA_2742  \
# DATE                                    ...
# 2019-11-01    228.0  0.000000    265.0  ...        15.0  202.396176
# 2019-11-02    108.0  0.000000    236.0  ...        15.0  202.396176
# 2019-11-03    308.0  0.000000    162.0  ...        15.0  202.396176
# 2019-11-04     95.0  3.000000     95.0  ...        15.0  202.396176
# 2019-11-05    125.0  0.000000    246.0  ...        15.0  202.396176
# ...             ...       ...      ...  ...         ...         ...
# 2020-01-27    118.0  7.603151    149.0  ...        15.0  205.637255
# 2020-01-28    135.0  7.603151    166.0  ...        15.0  205.637255
# 2020-01-29     77.0  7.603151    101.0  ...        15.0  205.637255
# 2020-01-30     39.0  0.000000    122.0  ...        15.0  205.637255
# 2020-01-31     38.0  7.603151     98.0  ...        15.0  205.637255
#
#             DELTA_2743  DELTA_2744  DELTA_2745  DELTA_2746  DELTA_2747  \
# DATE
# 2019-11-01  407.622437  407.622437  612.383518  582.933333  407.622437
# 2019-11-02  380.309537  380.309537  612.383518  582.933333  380.309537
# 2019-11-03  423.227243  423.227243  612.383518  582.933333  423.227243
# 2019-11-04  582.274939  582.274939  612.383518  582.933333  582.274939
# 2019-11-05  513.808989  513.808989  612.383518  582.933333  513.808989
# ...                ...         ...         ...         ...         ...
# 2020-01-27  414.904301  414.904301  614.969444  582.933333  414.904301
# 2020-01-28  411.301918  411.301918  614.969444  582.933333  411.301918
# 2020-01-29  418.423941  418.423941  614.969444  582.933333  418.423941
# 2020-01-30  400.926486  400.926486  614.969444  582.933333  400.926486
# 2020-01-31  416.842104  416.842104  614.969444  582.933333  416.842104
#
#             DELTA_2748  DELTA_2749  DELTA_2756
# DATE
# 2019-11-01  435.831081  116.787879  407.622437
# 2019-11-02  435.831081  116.787879  380.309537
# 2019-11-03  435.831081  116.787879  423.227243
# 2019-11-04  435.831081  116.787879  582.274939
# 2019-11-05  435.831081  116.787879  513.808989
# ...                ...         ...         ...
# 2020-01-27  435.831081  116.787879  414.904301
# 2020-01-28  435.831081  116.787879  411.301918
# 2020-01-29  435.831081  116.787879  418.423941
# 2020-01-30  435.831081  116.787879  400.926486
# 2020-01-31  435.831081  116.787879  416.842104
#
# [92 rows x 2747 columns]

# %%
#Todas las predicciones en un dataframe de 14 filas (2 ultimas semanas de test)
#para almacenar toda la informacion de los ARIMAs
dataframe_predicciones = data_sin_outliers[['DELTA_0', 'DELTA_1']] #Proceso "tosco"
dataframe_predicciones = dataframe_predicciones.drop(['DELTA_0', 'DELTA_1'], axis=1) #Proceso "tosco"
dataframe_predicciones = dataframe_predicciones[-14:] #Proceso "tosco"
dataframe_predicciones
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-01-18 00:00:00, 2020-01-19 00:00:00, 2020-01-20 00:00:00, 2020-01-21 00:00:00, 2020-01-22 00:00:00, 2020-01-23 00:00:00, 2020-01-24 00:00:00, 2020-01-25 00:00:00, 2020-01-26 00:00:00, 2020-01-27 00:00:00, 2020-01-28 00:00:00, 2020-01-29 00:00:00, 2020-01-30 00:00:00, 2020-01-31 00:00:00]

# %%
#Se itera por cada contador
for contador in tqdm(data['ID'].unique()):
  
    #1ºSe aisla el contador que se desea estudiar
    contador_a_estudiar = dataset_a_estudiar[f'DELTA_{contador}']

    #2ºUn modelo por contador
    train = contador_a_estudiar[:(92-14)]
    test = contador_a_estudiar[-14:]
    arima_model = auto_arima(train, 
                        start_p=0, 
                        d=1, 
                        start_q=0, 
                        max_p=7, 
                        max_d=7, 
                        max_q=7, 
                        start_P=0, 
                        D=1, 
                        start_Q=0, 
                        max_P=7, 
                        max_D=7, 
                        max_Q=7, 
                        m=12, 
                        seasonal=True, 
                        error_action='warn', 
                        trace=True, 
                        supress_warnings=True, 
                        stepwise=True, 
                        random_state=2517, 
                        n_fits=100)
    prediction = pd.DataFrame(arima_model.predict(n_periods = 14), index = test.index)

    #3ºLas predicciones por contador se pasan a una nueva columna del dataframe de return
    dataframe_predicciones[f'predict_cont_{contador}'] = prediction
# Out:
#   0%|          | 0/2747 [00:00<?, ?it/s]
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=839.642, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=804.086, Time=0.12 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=829.202, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=797.438, Time=0.36 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=798.554, Time=0.85 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=798.273, Time=0.86 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=800.227, Time=0.25 sec
#  ARIMA(1,1,0)(3,1,1)[12]             : AIC=800.273, Time=1.46 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=821.192, Time=0.23 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=795.018, Time=0.43 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=799.517, Time=0.29 sec
#  ARIMA(2,1,0)(3,1,0)[12]             : AIC=795.701, Time=0.99 sec
#   0%|          | 0/2747 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5280/3898454329.py in <module>
#       7     train = contador_a_estudiar[:(92-14)]
#       8     test = contador_a_estudiar[-14:]
# ----> 9     arima_model = auto_arima(train,
#      10                         start_p=0,
#      11                         d=1,
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\auto.py in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     715         )
#     716
# --> 717     sorted_res = search.solve()
#     718     return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#     719
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\_auto_solvers.py in solve(self)
#     349             if Q < max_Q and \
#     350                     self.k < self.max_k and \
# --> 351                     self._do_fit((p, d, q), (P, D, Q + 1, m)):
#     352                 Q += 1
#     353                 continue
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\_auto_solvers.py in _do_fit(self, order, seasonal_order, constant)
#     231             self.k += 1
#     232
# --> 233             fit, fit_time, new_ic = self._fit_arima(
#     234                 order=order,
#     235                 seasonal_order=seasonal_order,
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\_auto_solvers.py in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     504
#     505     try:
# --> 506         fit.fit(y, X=X, **fit_params)
#     507
#     508     # for non-stationarity errors or singular matrices, return None
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\arima.py in fit(self, y, X, **fit_args)
#     595
#     596         # Internal call
# --> 597         self._fit(y, X, **fit_args)
#     598
#     599         # now make a forecast if we're validating to compute the
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\arima.py in _fit(self, y, X, **fit_args)
#     516             with warnings.catch_warnings(record=False):
#     517                 warnings.simplefilter('ignore')
# --> 518                 fit, self.arima_res_ = _fit_wrapper()
#     519         else:
#     520             fit, self.arima_res_ = _fit_wrapper()
#
# C:\Python3.10\lib\site-packages\pmdarima\arima\arima.py in _fit_wrapper()
#     506             disp = fit_args.pop("disp", 0)
#     507
# --> 508             return arima, arima.fit(start_params=start_params,
#     509                                     method=method,
#     510                                     maxiter=_maxiter,
#
# C:\Python3.10\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702                 flags['hessian_method'] = optim_hessian
#     703             fargs = (flags,)
# --> 704             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                                fargs=fargs,
#     706                                                maxiter=maxiter,
#
# C:\Python3.10\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     561
#     562         optimizer = Optimizer()
# --> 563         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                        fargs, kwargs,
#     565                                                        hessian=hess,
#
# C:\Python3.10\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239
#     240         func = fit_funcs[method]
# --> 241         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                              disp=disp, maxiter=maxiter, callback=callback,
#     243                              retall=retall, full_output=full_output,
#
# C:\Python3.10\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     649         func = f
#     650
# --> 651     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     652                                      callback=callback, args=fargs,
#     653                                      bounds=bounds, disp=disp,
#
# C:\Python3.10\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# C:\Python3.10\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# C:\Python3.10\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# C:\Python3.10\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     529
#     530         def f(params, *args):
# --> 531             return -self.loglike(params, *args) / nobs
#     532
#     533         if method == 'newton':
#
# C:\Python3.10\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     937             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     938
# --> 939         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     940
#     941         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# C:\Python3.10\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# C:\Python3.10\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     901
#     902         # Initialize the state
# --> 903         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     904
#     905         # Run the filter
#
# C:\Python3.10\lib\site-packages\statsmodels\tsa\statespace\representation.py in _initialize_state(self, prefix, complex_step)
#     981             if not self.initialization.initialized:
#     982                 raise RuntimeError('Initialization is incomplete.')
# --> 983             self._statespaces[prefix].initialize(self.initialization,
#     984                                                  complex_step=complex_step)
#     985         else:
#
# KeyboardInterrupt:

# %%
data2 = pd.read_pickle('../data/arima_hasta_2400.pkl')
data2
# Out:
#             predict_cont_0  predict_cont_1  predict_cont_2  predict_cont_3  \
# DATE
# 2020-01-18      346.374206        6.737183       38.908300      471.775279
# 2020-01-19      265.689752        4.486606       38.098945      277.778903
# 2020-01-20      365.570080        3.018055       36.019619      340.531200
# 2020-01-21      356.358093        7.385677       46.344488      317.720288
# 2020-01-22      270.061836        9.130274       38.059881      423.156304
# 2020-01-23      248.713237        6.268221       34.178412      383.429773
# 2020-01-24      262.815579        3.998136       35.742352      337.484160
# 2020-01-25      272.182178        1.428094       33.129320      315.081118
# 2020-01-26      310.006146        1.135997       44.795888      314.761817
# 2020-01-27      186.522353        3.785206       42.453818      279.793260
# 2020-01-28      449.135420        3.398554       35.992391      421.501478
# 2020-01-29      332.580418        1.693673       39.297668      309.376849
# 2020-01-30      341.334940        6.906993       41.365983      493.024374
# 2020-01-31      354.542881        4.663789       40.556629      373.672436
#
#             predict_cont_4  predict_cont_5  predict_cont_6  predict_cont_7  \
# DATE
# 2020-01-18      103.962025             0.0      106.650175      189.977627
# 2020-01-19      196.063992             0.0      215.606830       29.544437
# 2020-01-20      318.806578             0.0      238.811720       59.624671
# 2020-01-21      194.849129             0.0      235.491911       53.772386
# 2020-01-22      156.833658             0.0      178.171196       90.586020
# 2020-01-23      197.735287             0.0      192.176087       37.618001
# 2020-01-24      199.748881             0.0      250.853196      152.980928
# 2020-01-25      153.787205             0.0      229.692632       36.875748
# 2020-01-26      198.574567             0.0      193.745684       75.919128
# 2020-01-27      163.981628             0.0      224.481068       77.638406
# 2020-01-28      225.470199             0.0      176.626253       57.506598
# 2020-01-29      162.353479             0.0      265.993791       36.604406
# 2020-01-30       79.113764             0.0      151.490076      188.006601
# 2020-01-31      149.529496             0.0      197.862841       27.573411
#
#             predict_cont_8  predict_cont_9  ...  predict_cont_2394  \
# DATE                                        ...
# 2020-01-18        0.918430       45.539666  ...          88.037428
# 2020-01-19        2.777290       -8.809393  ...          24.635365
# 2020-01-20        3.047814      -22.364962  ...          19.842772
# 2020-01-21        4.099232       50.264201  ...           8.196145
# 2020-01-22        1.467708       13.212599  ...          18.275754
# 2020-01-23        3.926902        3.790854  ...          70.913828
# 2020-01-24        0.366924       14.585437  ...          88.136264
# 2020-01-25        3.897690       -3.367888  ...         119.142856
# 2020-01-26        1.550685      -26.520233  ...         138.854927
# 2020-01-27        3.919958      -26.006581  ...          92.146111
# 2020-01-28        0.380990      -38.528878  ...         155.728147
# 2020-01-29        1.553311       22.868652  ...          57.505243
# 2020-01-30        0.522876       -2.599295  ...          56.609390
# 2020-01-31        3.730542      -45.282053  ...          39.289361
#
#             predict_cont_2395  predict_cont_2396  predict_cont_2397  \
# DATE
# 2020-01-18          59.304236         477.150813         194.464788
# 2020-01-19         110.333679         477.150813         194.524562
# 2020-01-20          52.858066         477.150813         258.454059
# 2020-01-21          39.282590         333.699551         114.204694
# 2020-01-22          47.497101         490.703898         156.150957
# 2020-01-23         137.937924         490.703898         316.102110
# 2020-01-24          81.614922         490.703898         273.575133
# 2020-01-25          33.437867         487.776483         145.788833
# 2020-01-26          53.809722         501.350664         188.297336
# 2020-01-27          -1.933318         595.866219         165.755253
# 2020-01-28          63.363560         390.050981         160.619485
# 2020-01-29          64.295795         718.201204         187.597311
# 2020-01-30          49.974407         734.494137         159.611631
# 2020-01-31          95.547844         734.494137         183.165958
#
#             predict_cont_2398  predict_cont_2399  predict_cont_2400  \
# DATE
# 2020-01-18         536.987849          31.550925         195.586349
# 2020-01-19         333.343301          36.490691         125.879659
# 2020-01-20         361.625924          36.946285         114.458259
# 2020-01-21         319.684274          56.231261          95.354147
# 2020-01-22         336.429873          51.492897          81.151933
# 2020-01-23         444.408143          65.027877         102.248788
# 2020-01-24         406.820928          40.339557         112.969150
# 2020-01-25         436.686120          52.181026         116.604660
# 2020-01-26         406.969557          49.609766         136.925202
# 2020-01-27         254.805493          36.814003         111.323494
# 2020-01-28         300.810475          48.948588         143.405392
# 2020-01-29         194.946738          51.636300          99.363548
# 2020-01-30         226.610106          29.763339         164.738615
# 2020-01-31         213.977427          67.897130         119.248562
#
#             predict_cont_2401  predict_cont_2402  predict_cont_2403
# DATE
# 2020-01-18         473.618992         409.651935         286.196387
# 2020-01-19         290.528194         323.392077         710.130850
# 2020-01-20         388.305114         397.676410         710.130850
# 2020-01-21         451.648755         383.671998         710.130850
# 2020-01-22         396.599360         379.560444         710.130850
# 2020-01-23         363.045414         385.184302         710.130850
# 2020-01-24         397.964359         359.435255         710.130850
# 2020-01-25         355.550494         345.390330         380.094844
# 2020-01-26         265.737626         349.140028         608.728237
# 2020-01-27         347.069726         390.582172         608.728237
# 2020-01-28         260.309405         318.925315         608.728237
# 2020-01-29         445.528604         423.284685         608.728237
# 2020-01-30         308.366609         411.319169         456.808845
# 2020-01-31         240.915407         341.926476         769.505279
#
# [14 rows x 2404 columns]

# %%
results_df = data2.T
results_df.columns = [['Dia_1','Dia_2','Dia_3','Dia_4','Dia_5','Dia_6','Dia_7',
                       'Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14']]
results_df['Semana_1'] = results_df[['Dia_1','Dia_2','Dia_3','Dia_4','Dia_5','Dia_6','Dia_7']].sum(axis=1)
results_df['Semana_2'] = results_df[['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14']].sum(axis=1)
results_df.drop(['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14'], axis=1, inplace=True)
results_df
# Out:
# C:\Users\Manuel\AppData\Local\Temp/ipykernel_540/2541943868.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   results_df.drop(['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14'], axis=1, inplace=True)
#                         Dia_1       Dia_2       Dia_3       Dia_4       Dia_5  \
# predict_cont_0     346.374206  265.689752  365.570080  356.358093  270.061836
# predict_cont_1       6.737183    4.486606    3.018055    7.385677    9.130274
# predict_cont_2      38.908300   38.098945   36.019619   46.344488   38.059881
# predict_cont_3     471.775279  277.778903  340.531200  317.720288  423.156304
# predict_cont_4     103.962025  196.063992  318.806578  194.849129  156.833658
# ...                       ...         ...         ...         ...         ...
# predict_cont_2399   31.550925   36.490691   36.946285   56.231261   51.492897
# predict_cont_2400  195.586349  125.879659  114.458259   95.354147   81.151933
# predict_cont_2401  473.618992  290.528194  388.305114  451.648755  396.599360
# predict_cont_2402  409.651935  323.392077  397.676410  383.671998  379.560444
# predict_cont_2403  286.196387  710.130850  710.130850  710.130850  710.130850
#
#                         Dia_6       Dia_7     Semana_1     Semana_2
# predict_cont_0     248.713237  262.815579  2115.582782  2246.304335
# predict_cont_1       6.268221    3.998136    41.024152    23.012305
# predict_cont_2      34.178412   35.742352   267.351996   277.591698
# predict_cont_3     383.429773  337.484160  2551.875906  2507.211332
# predict_cont_4     197.735287  199.748881  1367.999550  1132.810339
# ...                       ...         ...          ...          ...
# predict_cont_2399   65.027877   40.339557   318.079493   336.850152
# predict_cont_2400  102.248788  112.969150   827.648284   891.609473
# predict_cont_2401  363.045414  397.964359  2761.710190  2223.477871
# predict_cont_2402  385.184302  359.435255  2638.572419  2580.568175
# predict_cont_2403  710.130850  710.130850  4546.981485  4041.321916
#
# [2404 rows x 9 columns]

# %%
test2 = dataset_a_estudiar[-14:]
test2
# Out:
#             DELTA_0    DELTA_1  DELTA_2  DELTA_3  DELTA_4  DELTA_5  DELTA_6  \
# DATE
# 2020-01-18    421.0   0.000000     28.0    485.0   365.00      0.0    149.0
# 2020-01-19    273.0  11.690411     33.0    394.0   387.00      0.0    190.0
# 2020-01-20    306.0  14.000000     48.0    237.0   370.00      0.0    170.0
# 2020-01-21    292.0   3.000000     35.0    297.0   293.00      0.0    132.0
# 2020-01-22    460.0   0.000000     33.0    312.0   287.00      0.0    228.0
# 2020-01-23    331.0   3.000000     20.0    321.0   361.00      0.0    210.0
# 2020-01-24    368.0   5.670000     37.0    439.0   203.00      0.0    161.0
# 2020-01-25    390.0   1.330000     30.0    639.0   272.00      0.0    131.0
# 2020-01-26    304.0   3.000000     32.0    350.0   282.00      0.0    211.0
# 2020-01-27    213.0   4.000000     39.0    289.0   263.06      0.0    204.0
# 2020-01-28    232.0   1.000000     40.0    380.0   303.94      0.0    169.0
# 2020-01-29    403.0   2.000000     45.0    404.0   421.00      0.0    195.0
# 2020-01-30    425.0  10.000000     27.0    339.0   420.00      0.0    152.0
# 2020-01-31    255.0  11.690411     59.0    391.0   254.00      0.0    210.0
#
#                DELTA_7   DELTA_8  DELTA_9  ...  DELTA_2739  DELTA_2742  \
# DATE                                       ...
# 2020-01-18  144.052055  0.000000     29.0  ...        15.0  205.637255
# 2020-01-19  255.000000  0.000000    234.0  ...        15.0  205.637255
# 2020-01-20   76.000000  0.000000     80.0  ...        15.0  205.637255
# 2020-01-21   30.000000  5.000000    109.0  ...        15.0  205.637255
# 2020-01-22  202.000000  0.000000    128.0  ...        15.0  205.637255
# 2020-01-23   92.000000  0.000000    315.0  ...        15.0  205.637255
# 2020-01-24   28.000000  7.603151    409.0  ...        15.0  205.637255
# 2020-01-25   27.000000  0.000000    187.0  ...        15.0  205.637255
# 2020-01-26  328.000000  0.000000     88.0  ...        15.0  205.637255
# 2020-01-27  118.000000  7.603151    149.0  ...        15.0  205.637255
# 2020-01-28  135.000000  7.603151    166.0  ...        15.0  205.637255
# 2020-01-29   77.000000  7.603151    101.0  ...        15.0  205.637255
# 2020-01-30   39.000000  0.000000    122.0  ...        15.0  205.637255
# 2020-01-31   38.000000  7.603151     98.0  ...        15.0  205.637255
#
#             DELTA_2743  DELTA_2744  DELTA_2745  DELTA_2746  DELTA_2747  \
# DATE
# 2020-01-18  438.500082  438.500082  614.969444  582.933333  438.500082
# 2020-01-19  363.889917  363.889917  614.969444  582.933333  363.889917
# 2020-01-20  444.643897  444.643897  614.969444  582.933333  444.643897
# 2020-01-21  390.535651  390.535651  614.969444  582.933333  390.535651
# 2020-01-22  428.618820  428.618820  614.969444  582.933333  428.618820
# 2020-01-23  409.824931  409.824931  614.969444  582.933333  409.824931
# 2020-01-24  408.652628  408.652628  614.969444  582.933333  408.652628
# 2020-01-25  365.864302  365.864302  614.969444  582.933333  365.864302
# 2020-01-26  384.467399  384.467399  614.969444  582.933333  384.467399
# 2020-01-27  414.904301  414.904301  614.969444  582.933333  414.904301
# 2020-01-28  411.301918  411.301918  614.969444  582.933333  411.301918
# 2020-01-29  418.423941  418.423941  614.969444  582.933333  418.423941
# 2020-01-30  400.926486  400.926486  614.969444  582.933333  400.926486
# 2020-01-31  416.842104  416.842104  614.969444  582.933333  416.842104
#
#             DELTA_2748  DELTA_2749  DELTA_2756
# DATE
# 2020-01-18  435.831081  116.787879  438.500082
# 2020-01-19  435.831081  116.787879  363.889917
# 2020-01-20  435.831081  116.787879  444.643897
# 2020-01-21  435.831081  116.787879  390.535651
# 2020-01-22  435.831081  116.787879  428.618820
# 2020-01-23  435.831081  116.787879  409.824931
# 2020-01-24  435.831081  116.787879  408.652628
# 2020-01-25  435.831081  116.787879  365.864302
# 2020-01-26  435.831081  116.787879  384.467399
# 2020-01-27  435.831081  116.787879  414.904301
# 2020-01-28  435.831081  116.787879  411.301918
# 2020-01-29  435.831081  116.787879  418.423941
# 2020-01-30  435.831081  116.787879  400.926486
# 2020-01-31  435.831081  116.787879  416.842104
#
# [14 rows x 2747 columns]

# %%
test_3 = test2.T
test_3.columns = [['Dia_1','Dia_2','Dia_3','Dia_4','Dia_5','Dia_6','Dia_7',
                       'Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14']]
test_3['Semana_1'] = test_3[['Dia_1','Dia_2','Dia_3','Dia_4','Dia_5','Dia_6','Dia_7']].sum(axis=1)
test_3['Semana_2'] = test_3[['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14']].sum(axis=1)
test_3.drop(['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14'], axis=1, inplace=True)
test_3
# Out:
# C:\Users\Manuel\AppData\Local\Temp/ipykernel_540/172659562.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   test_3.drop(['Dia_8','Dia_9','Dia_10','Dia_11','Dia_12','Dia_13','Dia_14'], axis=1, inplace=True)
#                  Dia_1       Dia_2       Dia_3       Dia_4       Dia_5  \
# DELTA_0     421.000000  273.000000  306.000000  292.000000  460.000000
# DELTA_1       0.000000   11.690411   14.000000    3.000000    0.000000
# DELTA_2      28.000000   33.000000   48.000000   35.000000   33.000000
# DELTA_3     485.000000  394.000000  237.000000  297.000000  312.000000
# DELTA_4     365.000000  387.000000  370.000000  293.000000  287.000000
# ...                ...         ...         ...         ...         ...
# DELTA_2746  582.933333  582.933333  582.933333  582.933333  582.933333
# DELTA_2747  438.500082  363.889917  444.643897  390.535651  428.618820
# DELTA_2748  435.831081  435.831081  435.831081  435.831081  435.831081
# DELTA_2749  116.787879  116.787879  116.787879  116.787879  116.787879
# DELTA_2756  438.500082  363.889917  444.643897  390.535651  428.618820
#
#                  Dia_6       Dia_7     Semana_1     Semana_2
# DELTA_0     331.000000  368.000000  2451.000000  2222.000000
# DELTA_1       3.000000    5.670000    37.360411    33.020411
# DELTA_2      20.000000   37.000000   234.000000   272.000000
# DELTA_3     321.000000  439.000000  2485.000000  2792.000000
# DELTA_4     361.000000  203.000000  2266.000000  2216.000000
# ...                ...         ...          ...          ...
# DELTA_2746  582.933333  582.933333  4080.533333  4080.533333
# DELTA_2747  409.824931  408.652628  2884.665926  2812.730452
# DELTA_2748  435.831081  435.831081  3050.817568  3050.817568
# DELTA_2749  116.787879  116.787879   817.515152   817.515152
# DELTA_2756  409.824931  408.652628  2884.665926  2812.730452
#
# [2747 rows x 9 columns]

# %%
test_3.head(2404)
# Out:
#                 Dia_1       Dia_2      Dia_3      Dia_4       Dia_5  \
# DELTA_0     421.00000  273.000000  306.00000  292.00000  460.000000
# DELTA_1       0.00000   11.690411   14.00000    3.00000    0.000000
# DELTA_2      28.00000   33.000000   48.00000   35.00000   33.000000
# DELTA_3     485.00000  394.000000  237.00000  297.00000  312.000000
# DELTA_4     365.00000  387.000000  370.00000  293.00000  287.000000
# ...               ...         ...        ...        ...         ...
# DELTA_2399   15.00000    0.000000   49.00000   63.00000   46.000000
# DELTA_2400  106.04000  128.000000  104.71000   45.29000  132.690000
# DELTA_2401  329.96000  490.000000  514.00000  345.00000  666.000000
# DELTA_2402  448.25000  438.570000  391.04000  312.15484  450.833333
# DELTA_2403  501.25619  501.256190  501.25619  501.25619  501.256190
#
#                  Dia_6       Dia_7     Semana_1     Semana_2
# DELTA_0     331.000000  368.000000  2451.000000  2222.000000
# DELTA_1       3.000000    5.670000    37.360411    33.020411
# DELTA_2      20.000000   37.000000   234.000000   272.000000
# DELTA_3     321.000000  439.000000  2485.000000  2792.000000
# DELTA_4     361.000000  203.000000  2266.000000  2216.000000
# ...                ...         ...          ...          ...
# DELTA_2399   17.000000   30.000000   220.000000   232.501370
# DELTA_2400  101.310000   73.000000   691.040000   579.600000
# DELTA_2401  425.000000  495.000000  3264.960000  4016.944311
# DELTA_2402  450.833333  450.833333  2942.514840  2620.960000
# DELTA_2403  176.620000  252.600000  2935.500952  1513.770000
#
# [2404 rows x 9 columns]

# %%
def compute_error(pred, real):
    daily_rmses = []
    for i in range(7):
        daily_rmses.append((((real.iloc[:,i] - pred.iloc[:,i])**2/len(real.iloc[:,i])).sum())**(1/2))
    rmse_1 = sum(daily_rmses)/7
    
    first_week_pred_sum = pred.iloc[:,7].sum()
    second_week_pred_sum = pred.iloc[:,8].sum()
    first_week_real_sum = real.iloc[:,7].sum()
    second_week_real_sum = real.iloc[:,8].sum()
    
    first_week_rmse = (((first_week_real_sum - first_week_pred_sum)**2)/len(real.iloc[:,7]))**(1/2)
    second_week_rmse = (((second_week_real_sum - second_week_pred_sum)**2)/len(real.iloc[:,8]))**(1/2)
    rmse_2 = (first_week_rmse + second_week_rmse)/2
    
    return (rmse_1 + rmse_2)/2

# %%
compute_error(results_df, test_3)
# Out:
# 7855.446483657563

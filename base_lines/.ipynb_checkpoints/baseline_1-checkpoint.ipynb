# %% [markdown]
# Como primera baseline predecimos para cada contador y cada día el mismo consumo de agua que tuvo ese mismo contador ese mismo día del año pero el año pasado.
#
# Vamos a utilizar como test la última semana de Enero

# %%
import pandas as pd

data = pd.read_csv('../data/enriquecidos-003.csv')
data.head()
# Out:
#    Unnamed: 0        DATE  ID  READINGINTEGER  READINGTHOUSANDTH  \
# 0           0  2019-02-01   0         7963359                0.0
# 1           1  2019-02-01   1          139882                0.0
# 2           2  2019-02-01   2          190824                0.0
# 3           3  2019-02-01   3         3611828                0.0
# 4           4  2019-02-01   4         2723035                0.0
#
#    DELTAINTEGER  DELTATHOUSANDTH    YEAR  MONTH  DAY  ...  YEAR_DAY  \
# 0           243              0.0  2019.0    2.0  1.0  ...        32
# 1             8              0.0  2019.0    2.0  1.0  ...        32
# 2             0              0.0  2019.0    2.0  1.0  ...        32
# 3           492              0.0  2019.0    2.0  1.0  ...        32
# 4           247             56.0  2019.0    2.0  1.0  ...        32
#
#    sin_WEEK_DAY  cos_WEEK_DAY  sin_YEAR_DAY  cos_YEAR_DAY  MIN_TEMP  \
# 0     -0.433884     -0.900969      0.523416      0.852078      16.5
# 1     -0.433884     -0.900969      0.523416      0.852078      16.5
# 2     -0.433884     -0.900969      0.523416      0.852078      16.5
# 3     -0.433884     -0.900969      0.523416      0.852078      16.5
# 4     -0.433884     -0.900969      0.523416      0.852078      16.5
#
#    MEAN_TEMP  MAX_TEMP  SUN  PRECIPITATIONS
# 0       17.6      18.7  7.1             0.0
# 1       17.6      18.7  7.1             0.0
# 2       17.6      18.7  7.1             0.0
# 3       17.6      18.7  7.1             0.0
# 4       17.6      18.7  7.1             0.0
#
# [5 rows x 23 columns]

# %%
from datetime import datetime

def str2date2(string):
    return datetime.strptime(string, '%Y-%m-%d')

# %%
def mse(real, prediction):

# %%
january_last_week = [str2date2(i) for i in ["2020-1-25","2020-1-26","2020-1-27","2020-1-28","2020-1-29",
                                                       "2020-1-30","2020-1-31"]]
real = data.filter(data['DATE'] in january_last_week)
real.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\sergi\OneDrive\Escritorio\water_footprint\base_lines\baseline_1.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/sergi/OneDrive/Escritorio/water_footprint/base_lines/baseline_1.ipynb#ch0000003?line=0'>1</a> january_last_week = [str2date2(i) for i in ["2020-1-25","2020-1-26","2020-1-27","2020-1-28","2020-1-29",
#       <a href='vscode-notebook-cell:/c%3A/Users/sergi/OneDrive/Escritorio/water_footprint/base_lines/baseline_1.ipynb#ch0000003?line=1'>2</a>                                                        "2020-1-30","2020-1-31"]]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sergi/OneDrive/Escritorio/water_footprint/base_lines/baseline_1.ipynb#ch0000003?line=2'>3</a> real = data.filter(data['DATE'] in january_last_week)
#       <a href='vscode-notebook-cell:/c%3A/Users/sergi/OneDrive/Escritorio/water_footprint/base_lines/baseline_1.ipynb#ch0000003?line=3'>4</a> real.shape
#
# File ~\Anaconda3\envs\cajamar\lib\site-packages\pandas\core\generic.py:1535, in NDFrame.__nonzero__(self)
#    <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1532'>1533</a> @final
#    <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1533'>1534</a> def __nonzero__(self):
# -> <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1534'>1535</a>     raise ValueError(
#    <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1535'>1536</a>         f"The truth value of a {type(self).__name__} is ambiguous. "
#    <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1536'>1537</a>         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    <a href='file:///c%3A/Users/sergi/Anaconda3/envs/cajamar/lib/site-packages/pandas/core/generic.py?line=1537'>1538</a>     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

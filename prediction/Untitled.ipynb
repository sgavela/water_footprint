# %%
import pandas as pd

# %%
df8 = pd.read_pickle('../data/df8.pkl')
df8.head()
# Out:
#          ID  DELTA  YEAR_DAY       DATE  MEAN_CONSUMPTION  \
# 364635  999   7.00         0 2019-02-01        229.471233
# 364636  999   9.00         1 2019-02-02        229.471233
# 364637  999  42.04         2 2019-02-03        229.471233
# 364638  999  71.96         3 2019-02-04        229.471233
# 364639  999  25.00         4 2019-02-05        229.471233
#
#         VARIANCE_CONSUMPTION  WEEKDAY  IS_WEEKEND  sin_WEEKDAY  cos_WEEKDAY  \
# 364635          85169.268953        4           0    -0.433884    -0.900969
# 364636          85169.268953        5           1    -0.974928    -0.222521
# 364637          85169.268953        6           1    -0.781831     0.623490
# 364638          85169.268953        0           0     0.000000     1.000000
# 364639          85169.268953        1           0     0.781831     0.623490
#
#         sin_year_day  cos_year_day  PRECIPITATIONS  MIN_TEMP  MEAN_TEMP  \
# 364635      0.000000      1.000000             0.0      16.5       17.6
# ...

# %%
df8['TSPREDICTION'].iloc[364630].index[0]
# Out:
# 360
